# %% [markdown]
# # Women's imprisonment rates
# ## Criminal Justice Statistics Police Force Area: Custodial sentence lengths

# %% [markdown]
# #### Importing pandas library and reading in data

# %%
import pandas as pd
df = pd.read_csv('data/interim/PFA_2009-21_women_cust_comm_sus.csv')

# %%
df.head()
# Out:
#    year                pfa     sex     age_group  \
# 0  2009  Avon and Somerset  Female  Young adults
# 1  2009  Avon and Somerset  Female  Young adults
# 2  2009  Avon and Somerset  Female  Young adults
# 3  2009  Avon and Somerset  Female  Young adults
# 4  2009  Avon and Somerset  Female  Young adults
#
#                                 offence             outcome sentence_len  freq
# 0           Violence against the person  Community sentence          NaN     2
# 1           Violence against the person  Suspended sentence          NaN     1
# 2           Violence against the person  Suspended sentence          NaN     1
# 3                 Public order offences  Community sentence          NaN     1
# 4  Miscellaneous crimes against society  Community sentence          NaN     1

# %% [markdown]
# #### Filtering data for custodial sentences

# %%
filt = df['outcome'] == 'Immediate custody'
df2 = df[filt]
# filt2 = df['year'] >= 2014
# df2 = df[filt & filt2]

# %%
df2.head()
# Out:
#     year                pfa     sex     age_group  \
# 12  2009  Avon and Somerset  Female  Young adults
# 18  2009  Avon and Somerset  Female  Young adults
# 27  2009  Avon and Somerset  Female        Adults
# 30  2009  Avon and Somerset  Female        Adults
# 32  2009  Avon and Somerset  Female        Adults
#
#                                  offence            outcome  \
# 12                        Theft Offences  Immediate custody
# 18           Violence against the person  Immediate custody
# 27  Miscellaneous crimes against society  Immediate custody
# 30                        Theft Offences  Immediate custody
# 32                        Theft Offences  Immediate custody
#
#                                sentence_len  freq
# 12                            Up to 1 month     1
# 18       Imprisonment for public protection     1
# 27  More than 12 months and up to 18 months     1
# 30                            Up to 1 month     3
# 32                            Up to 1 month     1

# %% [markdown]
# #### Recategorising sentence lengths into less than six months and between six and 12 months

# %%
df2['sentence_len'].value_counts()
# Out:
# Up to 1 month                              12688
# More than 1 month and up to 2 months       10240
# More than 3 months and under 6 months       9664
# More than 2 months and up to 3 months       8219
# More than 2 years and up to 3 years         4678
# More than 12 months and up to 18 months     4361
# 6 months                                    3824
# More than 18 months and up to 2 years       3597
# More than 6 months and up to 9 months       3329
# 12 months                                   3005
# More than 3 years and under 4 years         1256
# More than 9 months and under 12 months      1148
# More than 4 years and up to 5 years         1117
# 4 years                                      992
# More than 5 years and up to 6 years          702
# More than 6 years and up to 7 years          360
# More than 7 years and up to 8 years          278
# Life sentence                                267
# More than 10 years and up to 15 years        184
# More than 8 years and up to 9 years          157
# More than 9 years and up to 10 years         133
# Imprisonment for public protection            82
# More than 15 years and less than life         49
# Name: sentence_len, dtype: int64

# %%
less_6months = ["Up to 1 month", 
                "More than 1 month and up to 2 months",
                "More than 2 months and up to 3 months",
                "More than 3 months and under 6 months"]

# %%
six_12_months = ["6 months",
                 "More than 6 months and up to 9 months",
                 "More than 9 months and under 12 months"]

# %%
filt = df2['sentence_len'].isin(less_6months)
df2.loc[filt, 'sentence_len'] = "Less than 6 months"
# Out:
# /Users/alex/opt/miniconda3/envs/women-PFA-outcomes/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
filt= df2['sentence_len'].isin(six_12_months)
df2.loc[filt, 'sentence_len'] = "6 months and under 12 months"

# %%
df2['sentence_len'].value_counts()
# Out:
# Less than 6 months                         40811
# 6 months and under 12 months                8301
# More than 2 years and up to 3 years         4678
# More than 12 months and up to 18 months     4361
# More than 18 months and up to 2 years       3597
# 12 months                                   3005
# More than 3 years and under 4 years         1256
# More than 4 years and up to 5 years         1117
# 4 years                                      992
# More than 5 years and up to 6 years          702
# More than 6 years and up to 7 years          360
# More than 7 years and up to 8 years          278
# Life sentence                                267
# More than 10 years and up to 15 years        184
# More than 8 years and up to 9 years          157
# More than 9 years and up to 10 years         133
# Imprisonment for public protection            82
# More than 15 years and less than life         49
# Name: sentence_len, dtype: int64

# %%
df2.head()
# Out:
#     year                pfa     sex     age_group  \
# 12  2009  Avon and Somerset  Female  Young adults
# 18  2009  Avon and Somerset  Female  Young adults
# 27  2009  Avon and Somerset  Female        Adults
# 30  2009  Avon and Somerset  Female        Adults
# 32  2009  Avon and Somerset  Female        Adults
#
#                                  offence            outcome  \
# 12                        Theft Offences  Immediate custody
# 18           Violence against the person  Immediate custody
# 27  Miscellaneous crimes against society  Immediate custody
# 30                        Theft Offences  Immediate custody
# 32                        Theft Offences  Immediate custody
#
#                                sentence_len  freq
# 12                       Less than 6 months     1
# 18       Imprisonment for public protection     1
# 27  More than 12 months and up to 18 months     1
# 30                       Less than 6 months     3
# 32                       Less than 6 months     1

# %%
filt1 = df2['sentence_len'] != "Less than 6 months"
filt2 = df2['sentence_len'] != "6 months and under 12 months"
filt = filt1 & filt2
df2.loc[filt, 'sentence_len'] = "Over 12 months"
# Out:
# /Users/alex/opt/miniconda3/envs/women–PFA-outcomes/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df2['sentence_len'].value_counts()
# Out:
# Less than 6 months              40811
# Over 12 months                  21218
# 6 months and under 12 months     8301
# Name: sentence_len, dtype: int64

# %% [markdown]
# ### Grouping for future analysis

# %%
df3 = df2.groupby(['pfa', 'year', 'sentence_len'], as_index=False)['freq'].sum()
df3
# Out:
#                     pfa  year                  sentence_len  freq
# 0     Avon and Somerset  2009  6 months and under 12 months    11
# 1     Avon and Somerset  2009            Less than 6 months   117
# 2     Avon and Somerset  2009                Over 12 months    37
# 3     Avon and Somerset  2010  6 months and under 12 months    16
# 4     Avon and Somerset  2010            Less than 6 months   113
# ...                 ...   ...                           ...   ...
# 1626          Wiltshire  2020            Less than 6 months    15
# 1627          Wiltshire  2020                Over 12 months    13
# 1628          Wiltshire  2021  6 months and under 12 months     3
# 1629          Wiltshire  2021            Less than 6 months    15
# 1630          Wiltshire  2021                Over 12 months    15
#
# [1631 rows x 4 columns]

# %% [markdown]
# #### Outputting to CSV

# %%
df3.to_csv('../data/interim/PFA_2009-21_women_cust_sentence_len.csv', index=False)

# %% [markdown]
# #### Checking the CSV

# %%
review = pd.read_csv('../data/interim/PFA_2009-21_women_cust_sentence_len.csv')
review.head()
# Out:
#                  pfa  year                  sentence_len  freq
# 0  Avon and Somerset  2009  6 months and under 12 months    11
# 1  Avon and Somerset  2009            Less than 6 months   117
# 2  Avon and Somerset  2009                Over 12 months    37
# 3  Avon and Somerset  2010  6 months and under 12 months    16
# 4  Avon and Somerset  2010            Less than 6 months   113

# %%
review.query('pfa == "Essex"')
# Out:
#        pfa  year                  sentence_len  freq
# 426  Essex  2009  6 months and under 12 months    25
# 427  Essex  2009            Less than 6 months   173
# 428  Essex  2009                Over 12 months    46
# 429  Essex  2010  6 months and under 12 months    18
# 430  Essex  2010            Less than 6 months   153
# 431  Essex  2010                Over 12 months    46
# 432  Essex  2011  6 months and under 12 months    20
# 433  Essex  2011            Less than 6 months   157
# 434  Essex  2011                Over 12 months    44
# 435  Essex  2012  6 months and under 12 months    16
# 436  Essex  2012            Less than 6 months   145
# 437  Essex  2012                Over 12 months    29
# 438  Essex  2013  6 months and under 12 months    14
# 439  Essex  2013            Less than 6 months   139
# 440  Essex  2013                Over 12 months    38
# 441  Essex  2014  6 months and under 12 months    17
# 442  Essex  2014            Less than 6 months   156
# 443  Essex  2014                Over 12 months    25
# 444  Essex  2015  6 months and under 12 months    11
# 445  Essex  2015            Less than 6 months   116
# 446  Essex  2015                Over 12 months    35
# 447  Essex  2016  6 months and under 12 months    10
# 448  Essex  2016            Less than 6 months   120
# 449  Essex  2016                Over 12 months    46
# 450  Essex  2017  6 months and under 12 months    19
# 451  Essex  2017            Less than 6 months   122
# 452  Essex  2017                Over 12 months    35
# 453  Essex  2018  6 months and under 12 months    16
# 454  Essex  2018            Less than 6 months   129
# 455  Essex  2018                Over 12 months    36
# 456  Essex  2019  6 months and under 12 months    12
# 457  Essex  2019            Less than 6 months   116
# 458  Essex  2019                Over 12 months    27
# 459  Essex  2020  6 months and under 12 months    10
# 460  Essex  2020            Less than 6 months    60
# 461  Essex  2020                Over 12 months    21
# 462  Essex  2021  6 months and under 12 months     6
# 463  Essex  2021            Less than 6 months    48
# 464  Essex  2021                Over 12 months    22

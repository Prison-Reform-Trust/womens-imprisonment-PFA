# %% [markdown]
# ## DATA CLEANING PROCESS
#  1. Lower case all current column names
#  2. Rename columns to new map
#  3. Remove numbered prefixes and standardise sentence length elements in dataframe with regex
#  4. Reorder columns
#  5. Converting certain columns to `category` type
#  6. Lower case all `outcomes`
#  7. Filtering the dataset for output

# %%
#Importing libraries
import pandas as pd
import glob

# %% [markdown]
# I'm going to avoid changing the current `utilities.py` functions and instead re-define them here for testing first.

# %%
def loadData():
    path="data/external/obo_sent_pivot_2010_2022/"
    cols = ['Police Force Area', 'Year', 'Sex', 'Age group', 'Offence group', 'Sentence Outcome', 'Custodial Sentence Length','Sentenced']
    all_files = glob.glob(path + "*.csv")
    all_csvs = [pd.read_csv(filename, usecols=cols, encoding= 'unicode_escape', low_memory=False) for filename in all_files]
    return pd.concat(all_csvs, axis=0, ignore_index=True)

# %%
df=loadData()
df.head()

# %%
def lcColumns(x_df):
    '''
    Converting all `x_df` columns to lowercase and replacing spaces with underscores

    Parameters
    ----------
    x_df: Pandas dataframe
    '''
    x_df.columns = x_df.columns.str.lower().str.replace(' ', '_')
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(lcColumns)
)
df_cleaned.head()

# %%
def renameColumns(x_df):
    mapping={
    'offence_group': 'offence',
    'police_force_area': 'pfa',
    'sentence_outcome': 'outcome',
    'custodial_sentence_length': 'sentence_length',
    'sentenced': 'freq'
    }
    
    x_df = x_df.rename(columns=mapping)
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(lcColumns)
    .pipe(renameColumns)
)
df_cleaned.head()

# %%
def removePrefix(x_df):
    """
    Remove numbered prefixes from all elements in dataframe

    Parameters
    ----------
    x_df: Pandas dataframe

    Returns
    -------
    Dataframe
        Dataframe with regex parameters replaced
    """
    cols = x_df.select_dtypes(include='object').columns
    for col in cols:
        x_df[col] = x_df[col].str.replace('^\d+:', '', regex=True).str.lstrip()
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
)
df_cleaned.head()

# %%
def standardiseSentences(x_df, col):
    mapping = {r"^\S* - ": "",
        "(Over)": "More than",
        "(to less than)": "and under",
        "Life$": "Life sentence",
        }
    x_df[col].replace(regex=mapping, inplace=True)
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
)
df_cleaned.head()

# %%
def orderColumns(x_df):
    '''
    Set column order for dataframe

    Parameters
    ----------
    x_df: Pandas dataframe
    '''
    column_order = ['year', 'pfa', 'sex', 'age_group', 'offence', 'outcome', 'sentence_length', 'freq']

    x_df = x_df.reindex(columns=column_order)
    return x_df

# %%
def removeTotal(x_df, col):
    x_df[col] = x_df[col].str.replace("Total ", "").str.capitalize()
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(removeTotal, 'outcome')
    .pipe(orderColumns)
)
df_cleaned.head()

# %%
df_cleaned.info()

# %%
def categoryColumns(x_df):
    cols = x_df.select_dtypes(include='object').columns
    for col in cols:
        ratio = len(x_df[col].value_counts()) / len(x_df)
        if ratio < 0.05:
            x_df[col] = x_df[col].astype('category')
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(removeTotal, 'outcome')
    .pipe(orderColumns)
    .pipe(categoryColumns)
)
df_cleaned.head()

# %%
df_cleaned.info()

# %% [markdown]
# Given how significant the difference in memory usage is once following the conversion of the `object` columns, I might change the order of the `categoryColumns()` function. Let's see if it makes a time difference.

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(categoryColumns)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(removeTotal, 'outcome')
    .pipe(orderColumns)
)
df_cleaned.head()

# %% [markdown]
# Right, that didn't quite work! Looking back it appears as though the `removePrefix()` function is the issue, as it specifies columns must be `object` type. Let's update this and run again.

# %%
def removePrefix(x_df):
    """
    Remove numbered prefixes from all elements in dataframe

    Parameters
    ----------
    x_df: Pandas dataframe

    Returns
    -------
    Dataframe
        Dataframe with regex parameters replaced
    """
    cols = x_df.select_dtypes(include='category').columns
    for col in cols:
        x_df[col] = x_df[col].str.replace('^\d+:', '', regex=True).str.lstrip()
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(categoryColumns)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(removeTotal, 'outcome')
    .pipe(orderColumns)
)
df_cleaned.head()

# %% [markdown]
# Much quicker!
#
# I'm also going to loop back up and combine the next stage of `str.capitalize()` for the `outcome` column into the `removeTotal()` function.

# %% [markdown]
# I also suspect that this whole operation can be sped up by filtering the dataset as the first step. So let's define this next and then reorder the `pipe()` functions.

# %%
df.columns

# %%
df['Police Force Area'].unique()

# %%
def filterDataFrame(x_df):
    filt1 = x_df['Sex'] == '01: Female'
    filt2 = x_df['Sentence Outcome'].isin(['06: Total Immediate Custody', '04: Total Community sentence','05: Suspended Sentence'])
    filt3 = x_df['Age group'].isin(['02: Young adults', '03: Adults'])
    filt4 = x_df['Police Force Area'].isin(['City of London', 'Not known'])
    filt = filt1 & filt2 & filt3 & ~filt4
    women_dataset = x_df[filt].sort_values(['Year', 'Police Force Area']).copy()
    return women_dataset

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(filterDataFrame)
    .pipe(categoryColumns)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(removeTotal, 'outcome')
    .pipe(orderColumns)
)
df_cleaned.head()

# %% [markdown]
# Wow, that was quick! I'm going to need to double check this has completed all of the stages.

# %% [markdown]
# What has been completed?
# * It's filtered
# * Columns are lowercase
# * Columns are renamed
# * Prefixes are removed
# * Total has been removed from `outcome`
# * Column order has been changed
#
# What needs further checking?
# * Have `object` columns been changed to `category`
# * Have `sentence_length` values been standardised

# %%
df_cleaned.info()

# %% [markdown]
# Hmmmmm, no to the first question then!
#
# What's gone on here?

# %% [markdown]
# Let's adjust the `ratio` component of the `categoryColumns` function and see if that makes a difference

# %%
def categoryColumns(x_df):
    cols = x_df.select_dtypes(include='object').columns
    for col in cols:
        ratio = len(x_df[col].value_counts()) / len(x_df)
        if ratio < 0.5:
            x_df[col] = x_df[col].astype('category')
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(filterDataFrame)
    .pipe(categoryColumns)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(removeTotal, 'outcome')
    .pipe(orderColumns)
)
df_cleaned.head()

# %%
df_cleaned.info()

# %% [markdown]
# Nope, that hasn't made a difference

# %%
def filterDataFrame(x_df):
    filt1 = x_df['Sex'] == '01: Female'
    filt2 = x_df['Sentence Outcome'].isin(['06: Total Immediate Custody', '04: Total Community sentence','05: Suspended Sentence'])
    filt3 = x_df['Age group'].isin(['02: Young adults', '03: Adults'])
    filt4 = x_df['Police Force Area'].isin(['City of London', 'Not known'])
    filt = filt1 & filt2 & filt3 & ~filt4
    return x_df[filt].sort_values(['Year', 'Police Force Area'])

# %% [markdown]
# Let's run this again with a slight change to the return statement of `filterDataFrame()`

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(filterDataFrame)
    .pipe(categoryColumns)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(removeTotal, 'outcome')
    .pipe(orderColumns)
)
df_cleaned.head()

# %%
def categoryColumns(x_df):
    cols = x_df.select_dtypes(include='object').columns
    for col in cols:
        ratio = len(x_df[col].value_counts()) / len(x_df)
        if ratio < 0.05:
            x_df[col] = x_df[col].astype('category')
    return x_df

# %%
cols = df_cleaned.select_dtypes(include='object').columns
for col in cols:
    ratio = len(df_cleaned[col].value_counts()) / len(df_cleaned)
    print(f'Column: {col}, Ratio: {ratio:.20f}')

# %%
cols = df.select_dtypes(include='object').columns
for col in cols:
    ratio = len(df[col].value_counts()) / len(df)
    print(f'Column: {col}, Ratio: {ratio:.20f}')

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(filterDataFrame)
    .pipe(categoryColumns)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix) # It appears to be at this stage that the categorised columns change back to object as a result of the `.replace()` function
    
)
df_cleaned.info()

# %% [markdown]
# Okay, so let's adjust the `removePrefix()` function and change some of the ordering so `categoryColumns()` comes after.

# %%
def removePrefix(x_df):
    """
    Remove numbered prefixes from all elements in dataframe

    Parameters
    ----------
    x_df: Pandas dataframe

    Returns
    -------
    Dataframe
        Dataframe with regex parameters replaced
    """
    cols = x_df.select_dtypes(include='object').columns
    for col in cols:
        x_df[col] = x_df[col].str.replace('^\d+:', '', regex=True).str.lstrip()
    return x_df

# %%
my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(filterDataFrame)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(removeTotal, 'outcome')
    .pipe(categoryColumns)
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(orderColumns)
    
)
df_cleaned.info()

# %% [markdown]
# Right, I think we're there. Let's consolidate.

# %%
.pipe(filterDataFrame)
.pipe(lcColumns)
.pipe(renameColumns)
.pipe(removePrefix)
.pipe(removeTotal, 'outcome')
.pipe(categoryColumns)
.pipe(standardiseSentences, 'sentence_length')
.pipe(orderColumns)

# %%
def loadData():
    path="data/external/obo_sent_pivot_2010_2022/"
    cols = ['Police Force Area', 'Year', 'Sex', 'Age group', 'Offence group', 'Sentence Outcome', 'Custodial Sentence Length','Sentenced']
    all_files = glob.glob(path + "*.csv")
    all_csvs = [pd.read_csv(filename, usecols=cols, encoding= 'unicode_escape', low_memory=False) for filename in all_files]
    return pd.concat(all_csvs, axis=0, ignore_index=True)

def filterDataFrame(x_df):
    filt1 = x_df['Sex'] == '01: Female'
    filt2 = x_df['Sentence Outcome'].isin(['06: Total Immediate Custody', '04: Total Community sentence','05: Suspended Sentence'])
    filt3 = x_df['Age group'].isin(['02: Young adults', '03: Adults'])
    filt4 = x_df['Police Force Area'].isin(['City of London', 'Not known'])
    filt = filt1 & filt2 & filt3 & ~filt4
    return x_df[filt].sort_values(['Year', 'Police Force Area'])

def lcColumns(x_df):
    '''
    Converting all `x_df` columns to lowercase and replacing spaces with underscores

    Parameters
    ----------
    x_df: Pandas dataframe
    '''
    x_df.columns = x_df.columns.str.lower().str.replace(' ', '_')
    return x_df

def renameColumns(x_df):
    mapping={
    'offence_group': 'offence',
    'police_force_area': 'pfa',
    'sentence_outcome': 'outcome',
    'custodial_sentence_length': 'sentence_length',
    'sentenced': 'freq'
    }
    
    x_df = x_df.rename(columns=mapping)
    return x_df

def removePrefix(x_df):
    """
    Remove numbered prefixes from all elements in dataframe

    Parameters
    ----------
    x_df: Pandas dataframe

    Returns
    -------
    Dataframe
        Dataframe with regex parameters replaced
    """
    cols = x_df.select_dtypes(include='object').columns
    for col in cols:
        x_df[col] = x_df[col].str.replace('^\d+:', '', regex=True).str.lstrip()
    return x_df
    
def removeTotal(x_df, col):
    x_df[col] = x_df[col].str.replace("Total ", "").str.capitalize()
    return x_df

def categoryColumns(x_df):
    cols = x_df.select_dtypes(include='object').columns
    for col in cols:
        ratio = len(x_df[col].value_counts()) / len(x_df)
        if ratio < 0.05:
            x_df[col] = x_df[col].astype('category')
    return x_df

def standardiseSentences(x_df, col):
    mapping = {r"^\S* - ": "",
        "(Over)": "More than",
        "(to less than)": "and under",
        "Life$": "Life sentence",
        }
    x_df[col].replace(regex=mapping, inplace=True)
    return x_df

def orderColumns(x_df):
    '''
    Set column order for dataframe

    Parameters
    ----------
    x_df: Pandas dataframe
    '''
    column_order = ['year', 'pfa', 'sex', 'age_group', 'offence', 'outcome', 'sentence_length', 'freq']

    x_df = x_df.reindex(columns=column_order)
    return x_df

# %%
df=loadData()

my_df = df.copy()
df_cleaned=(
    my_df
    .pipe(filterDataFrame)
    .pipe(lcColumns)
    .pipe(renameColumns)
    .pipe(removePrefix)
    .pipe(removeTotal, 'outcome')
    .pipe(standardiseSentences, 'sentence_length')
    .pipe(categoryColumns)
    .pipe(orderColumns)   
)
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243344 entries, 1915 to 2533630
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   year             243344 non-null  int64
#  1   pfa              243344 non-null  category
#  2   sex              243344 non-null  category
#  3   age_group        243344 non-null  category
#  4   offence          243344 non-null  category
#  5   outcome          243344 non-null  category
#  6   sentence_length  243344 non-null  category
#  7   freq             243344 non-null  int64
# dtypes: category(6), int64(2)
# memory usage: 7.0 MB

# %%
df_cleaned.head()
# Out:
#       year                pfa     sex     age_group  \
# 1915  2010  Avon and Somerset  Female  Young adults
# 1997  2010  Avon and Somerset  Female  Young adults
# 2052  2010  Avon and Somerset  Female  Young adults
# 2053  2010  Avon and Somerset  Female  Young adults
# 2054  2010  Avon and Somerset  Female  Young adults
#
#                           offence             outcome sentence_length  freq
# 1915  Violence against the person  Community sentence       Not known     1
# 1997                Drug offences  Community sentence       Not known     1
# 2052  Violence against the person   Immediate custody   Life sentence     1
# 2053  Violence against the person  Community sentence       Not known     1
# 2054  Violence against the person  Suspended sentence       Not known     1

# %%
df_cleaned.to_csv('data/interim/new_pipeline.csv', index=False)

# %%
df_cleaned_import = pd.read_csv('data/interim/new_pipeline.csv')
df_cleaned_import
# Out:
#         year                pfa     sex     age_group  \
# 0       2010  Avon and Somerset  Female  Young adults
# 1       2010  Avon and Somerset  Female  Young adults
# 2       2010  Avon and Somerset  Female  Young adults
# 3       2010  Avon and Somerset  Female  Young adults
# 4       2010  Avon and Somerset  Female  Young adults
# ...      ...                ...     ...           ...
# 243339  2022          Wiltshire  Female        Adults
# 243340  2022          Wiltshire  Female        Adults
# 243341  2022          Wiltshire  Female        Adults
# 243342  2022          Wiltshire  Female        Adults
# 243343  2022          Wiltshire  Female        Adults
#
#                                      offence             outcome  \
# 0                Violence against the person  Community sentence
# 1                              Drug offences  Community sentence
# 2                Violence against the person   Immediate custody
# 3                Violence against the person  Community sentence
# 4                Violence against the person  Suspended sentence
# ...                                      ...                 ...
# 243339                        Fraud Offences  Suspended sentence
# 243340                  Summary non-motoring  Community sentence
# 243341                      Summary motoring  Community sentence
# 243342  Miscellaneous crimes against society  Community sentence
# 243343                      Summary motoring  Suspended sentence
#
#        sentence_length  freq
# 0            Not known     1
# 1            Not known     1
# 2        Life sentence     1
# 3            Not known     1
# 4            Not known     1
# ...                ...   ...
# 243339       Not known     1
# 243340       Not known     1
# 243341       Not known     1
# 243342       Not known     1
# 243343       Not known     1
#
# [243344 rows x 8 columns]

# %%
df_original = pd.read_csv('data/interim/PFA_2010-22_women_cust_comm_sus.csv')
df_original
# Out:
#         year                pfa     sex     age_group  \
# 0       2010  Avon and Somerset  Female  Young adults
# 1       2010  Avon and Somerset  Female  Young adults
# 2       2010  Avon and Somerset  Female  Young adults
# 3       2010  Avon and Somerset  Female  Young adults
# 4       2010  Avon and Somerset  Female  Young adults
# ...      ...                ...     ...           ...
# 243339  2022          Wiltshire  Female        Adults
# 243340  2022          Wiltshire  Female        Adults
# 243341  2022          Wiltshire  Female        Adults
# 243342  2022          Wiltshire  Female        Adults
# 243343  2022          Wiltshire  Female        Adults
#
#                                      offence             outcome  \
# 0                Violence against the person  Community sentence
# 1                              Drug offences  Community sentence
# 2                Violence against the person   Immediate custody
# 3                Violence against the person  Community sentence
# 4                Violence against the person  Suspended sentence
# ...                                      ...                 ...
# 243339                        Fraud Offences  Suspended sentence
# 243340                  Summary non-motoring  Community sentence
# 243341                      Summary motoring  Community sentence
# 243342  Miscellaneous crimes against society  Community sentence
# 243343                      Summary motoring  Suspended sentence
#
#        sentence_length  freq
# 0         24:Not known     1
# 1         24:Not known     1
# 2        Life sentence     1
# 3         24:Not known     1
# 4         24:Not known     1
# ...                ...   ...
# 243339    24:Not known     1
# 243340    24:Not known     1
# 243341    24:Not known     1
# 243342    24:Not known     1
# 243343    24:Not known     1
#
# [243344 rows x 8 columns]

# %% [markdown]
# Great, that looks fine. Now to replace elements in `utilities.py` and `data_cleansing.py`
